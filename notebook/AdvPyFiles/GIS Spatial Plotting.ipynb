# %% [markdown]
# ## Examples of plotting maps and GIS data
#
# This notebook requires a few specialized libraries not found in most MSI Python environments. These examples have been tested to work with the `python-rich/3.10_msi1.0` module.
#
# To build your own environment with the needed modules, see `binder/environment.yml` in this repository. The BinderHub link uses that environment and thus should also work out of the box.

# %% [markdown]
# ## Plotting geographic information with Cartopy
#
# The fundamental elements of geographic plotting are coordinates and projections. Here we use `cartopy` to manage projecting lat/lon coordinates onto a world map.
#
# First we load some additional modules, then place some lines/marks/labels on a map.

# %%
import datetime
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()

ny_lon, ny_lat = -75, 43
delhi_lon, delhi_lat = 77.23, 28.61

plt.plot([ny_lon, delhi_lon], [ny_lat, delhi_lat],
         color='blue', linewidth=2, marker='o',
         transform=ccrs.Geodetic(),
         )

plt.plot([ny_lon, delhi_lon], [ny_lat, delhi_lat],
         color='gray', linestyle='--',
         transform=ccrs.PlateCarree(),
         )

plt.text(ny_lon - 3, ny_lat - 12, 'New York',
         horizontalalignment='right',
         transform=ccrs.Geodetic())

plt.text(delhi_lon + 3, delhi_lat - 12, 'Delhi',
         horizontalalignment='left',
         transform=ccrs.Geodetic())

plt.show()

# %% [markdown]
# The `cartopy` install includes some sample data files. Here we show plotting

# %%
import cartopy.feature

# %%
import os
import matplotlib.pyplot as plt
from matplotlib import colormaps
from netCDF4 import Dataset as netcdf_dataset
import numpy as np

from cartopy import config
import cartopy.crs as ccrs


# get the path of the file. It can be found in the repo data directory.
fname = os.path.join(config["repo_data_dir"],
                     'netcdf', 'HadISST1_SST_update.nc'
                     )

dataset = netcdf_dataset(fname)
sst = dataset.variables['sst'][0, :, :]
lats = dataset.variables['lat'][:]
lons = dataset.variables['lon'][:]

ax = plt.axes(projection=ccrs.PlateCarree())

plt.contourf(lons, lats, sst, 60,
             cmap=colormaps['gist_heat'],
             transform=ccrs.PlateCarree())

ax.coastlines()

plt.show()

# %% [markdown]
# ## Plotting geographic information with Basemap
#
# For a few years Basemap was deprecated in favor of Cartopy, but both are now supported again. Generally speaking, Cartopy focuses on drawing geometrical elements on maps, while Basemap is more oriented to plotting datasets.
#
# First we load some additional modules:

# %%
from mpl_toolkits.basemap import Basemap
from netCDF4 import Dataset, date2index
from datetime import datetime

# %% [markdown]
# A simple example: plot a world map with the current day/night shaded

# %%
# miller projection 
map = Basemap(projection='mill',lon_0=180)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(-90,90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(map.lonmin,map.lonmax+30,60),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
# shade the night areas, with alpha transparency so the 
# map shows through. Use current time in UTC.
date = datetime.utcnow()
CS=map.nightshade(date)
plt.title('Day/Night Map for %s (UTC)' % date.strftime("%d %b %Y %H:%M:%S"))
plt.show()

# %% [markdown]
# Now for a more complex example.
#
# Here we read in the sea surface temps and ice from NOAA. See how easy it is to fetch external datasets!
#
# This example is based on the SST example from the [Basemap examples page](https://matplotlib.org/basemap/stable/users/examples.html), although the example on that page has evolved somewhat since this demo was made.
#
# Note that this and the following step may take several seconds to execute. The speed depends on how rapidly the NOAA server returns the requested data.

# %%
date = datetime( 2017,10,1,0) # date to plot.
# open dataset.
dataset = Dataset('http://psl.noaa.gov/thredds/dodsC/Datasets/noaa.oisst.v2/sst.wkmean.1990-present.nc')
icedata = Dataset('http://psl.noaa.gov/thredds/dodsC/Datasets/noaa.oisst.v2/icec.wkmean.1990-present.nc')
timevar = dataset.variables['time']
timeindex = date2index(date,timevar) # find time index for desired date.

# %% [markdown]
# Create some variables. Read ``sst`` and ``ice`` from the dataset we just downloaded, and make a grid of latitude and longitude.

# %%
# read sst.  Will automatically create a masked array using
# missing_value variable attribute. 'squeeze out' singleton dimensions.
sst = dataset.variables['sst'][timeindex,:].squeeze()
# read ice.
ice = icedata.variables['icec'][timeindex,:].squeeze()
# read lats and lons (representing centers of grid boxes).
lats = dataset.variables['lat'][:]
lons = dataset.variables['lon'][:]
lons, lats = np.meshgrid(lons,lats)

# %% [markdown]
# Some fiddling since the format of the land and ice masks changed since we wrote this example.

# %%
land = ice.copy()
land.data[:] = 0
land.mask = ~land.mask[:]
ice.mask[np.where(ice.data == 0)] = True

# %% [markdown]
# Next we set up a figure and a map projection

# %%
fig = plt.figure()
ax = fig.add_axes([0.05,0.05,0.9,0.9])
# create Basemap instance without coastlines
m = Basemap(projection='kav7',lon_0=0,resolution=None)
m.drawmapboundary(fill_color='0.3')

# %% [markdown]
# Finally, we plot the data onto our world map.

# %%
# plot sst, then ice with pcolor
im1 = m.pcolormesh(lons,lats,sst,shading='gouraud',cmap=plt.cm.hot,latlon=True)
im2 = m.pcolormesh(lons,lats,ice,shading='gouraud',cmap=plt.cm.gist_rainbow,latlon=True)
im3 = m.pcolormesh(lons,lats,land,shading='gouraud',cmap=plt.cm.hot,latlon=True)
# draw parallels and meridians, but don't bother labelling them.
m.drawparallels(np.arange(-90.,99.,30.))
m.drawmeridians(np.arange(-180.,180.,60.))
# add colorbar
cb = m.colorbar(im1,"bottom", size="5%", pad="2%")
# add a title.
plt.title('SST and ICE analysis for %s'%date)
plt.show()
